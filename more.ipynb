# %%
# !rm -rf forgooglecollab2
# !git clone https://github.com/Veterse/forgooglecollab2.git
# %cd forgooglecollab2
# !pip install python-chess
# !python main_distributed.py
# Out:
# Cloning into 'forgooglecollab2'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (145/145), done.
# remote: Compressing objects: 100% (117/117), done.
# remote: Total 145 (delta 27), reused 142 (delta 24), pack-reused 0 (from 0)
# Receiving objects: 100% (145/145), 62.54 MiB | 10.49 MiB/s, done.
# Resolving deltas: 100% (27/27), done.
# /content/forgooglecollab2
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 76.2 MB/s eta 0:00:00ta 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for chess: filename=chess-1.11.2-py3-none-any.whl size=147775 sha256=f5e11cf7b7ec1fa600bd72b5c11b572f07d956111e0ed18d20963e3819e4d0bf
#   Stored in directory: /root/.cache/pip/wheels/83/1f/4e/8f4300f7dd554eb8de70ddfed96e94d3d030ace10c5b53d447
# Successfully built chess
# ...
# 2025-11-30 20:30:50,296 [INFO] [MainProcess] Starting distributed training system with Shared Model and Memory Buffer...
# ...

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found
